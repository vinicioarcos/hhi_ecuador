# %% [markdown]
# # Replicación HHI y DEA - Afzal 2021 UAE
#
# Notebook base para validar la réplica.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

root = Path('..')
hhi = pd.read_csv(root/'data/processed/hhi_values_from_paper_table3.csv')
hhi

# %%
plt.figure()
plt.plot(hhi['year'], hhi['hhi_paper'], marker='o')
plt.xlabel('Year')
plt.ylabel('HHI')
plt.title('HHI values reported in paper')
plt.show()

# %% [markdown]
# ## Próximo paso
#
# Completar `data/raw/hhi/gfcf_sector_template.csv` con los datos originales de Bayanat/UAE Open Data y ejecutar `src/hhi.py`.
